# %%
import shutil
shutil.copytree(r'../input/flower/flower_dataset',r'./data')
# Out:
# './data'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, transforms, models
from torch.utils.data import random_split
import os
import time
import copy
import matplotlib.pyplot as plt

# Set data directory
data_dir = '/kaggle/working/data'

# Data augmentation and normalization for training and validation
data_transforms = transforms.Compose([
        # GRADED FUNCTION: Add five data augmentation methods, Normalizating and Tranform to tensor
        ### START SOLUTION HERE ###
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(30),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ### END SOLUTION HERE ###
])

# Load the entire dataset
full_dataset = datasets.ImageFolder(data_dir, data_transforms)

# Automatically split into 80% train and 20% validation
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Use DataLoader for both train and validation datasets
batch_size = 32
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

dataloaders = {'train': train_loader, 'val': val_loader}
dataset_sizes = {'train': len(train_dataset), 'val': len(val_dataset)}

# Get class names from the dataset
class_names = full_dataset.classes

# Load pre-trained model and modify the last layer
model = models.resnet18(pretrained=True)


# GRADED FUNCTION: Modify the last fully connected layer of model
### START SOLUTION HERE ###
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(class_names))
### END SOLUTION HERE ###



# GRADED FUNCTION: Define the loss function
### START SOLUTION HERE ###
criterion = nn.CrossEntropyLoss()
### END SOLUTION HERE ###

# GRADED FUNCTION: Define the optimizer
### START SOLUTION HERE ###
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
### END SOLUTION HERE ###

# Learning rate scheduler
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# Training function
def train_model(model, criterion, optimizer, scheduler, num_epochs=25, model_name='resnet'):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Print learning rate for current epoch
        current_lr = optimizer.param_groups[0]['lr']
        print(f'Learning Rate: {current_lr:.6f}')

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()  # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        
                        # GRADED FUNCTION: Backward pass and optimization
                        ### START SOLUTION HERE ###
                        loss.backward()
                        optimizer.step()
                        ### END SOLUTION HERE ###

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                scheduler.step()  # Update learning rate based on scheduler

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Save the model if validation accuracy is the best so far
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                # Save the best model
                save_dir = 'Ex2/work_dir'
                os.makedirs(save_dir, exist_ok=True)

               # GRADED FUNCTION: Save the best model
                ### START SOLUTION HERE ###
                torch.save(model.state_dict(), os.path.join(save_dir, 'best_model.pth'))
                ### END SOLUTION HERE ###

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    model.load_state_dict(best_model_wts)
    # 返回loss曲线
    return model, train_losses, val_losses

def plot_loss_curves(loss_dict):
    plt.figure(figsize=(10,6))
    for model_name, (train_losses, val_losses) in loss_dict.items():
        plt.plot(train_losses, label=f'{model_name} Train Loss')
        plt.plot(val_losses, label=f'{model_name} Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss Curves')
    plt.legend()
    plt.grid()
    plt.show()

# Train the model
if __name__ == '__main__':
    loss_dict = {}

    for model_name, model_fn in [('resnet18', models.resnet18), ('resnet34', models.resnet34), ('resnet50', models.resnet50)]:
        model = model_fn(pretrained=True)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, len(class_names))
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
        scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
        model, train_losses, val_losses = train_model(model, criterion, optimizer, scheduler, num_epochs=25, model_name=model_name)
        loss_dict[model_name] = (train_losses, val_losses)

    plot_loss_curves(loss_dict)
# Out:
# Epoch 0/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.9215 Acc: 0.6629
# val Loss: 0.5160 Acc: 0.8228
#
# Epoch 1/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.4617 Acc: 0.8428
# val Loss: 0.4051 Acc: 0.8561
#
# Epoch 2/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.4013 Acc: 0.8464
# val Loss: 0.3967 Acc: 0.8509
#
# Epoch 3/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3925 Acc: 0.8600
# val Loss: 0.3360 Acc: 0.8877
#
# Epoch 4/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3406 Acc: 0.8723
# val Loss: 0.3248 Acc: 0.8912
#
# Epoch 5/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3005 Acc: 0.8924
# val Loss: 0.3072 Acc: 0.8947
#
# Epoch 6/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3037 Acc: 0.8845
# val Loss: 0.3432 Acc: 0.8807
#
# Epoch 7/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2832 Acc: 0.8999
# val Loss: 0.2896 Acc: 0.9140
#
# Epoch 8/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2702 Acc: 0.9034
# val Loss: 0.2887 Acc: 0.9018
#
# Epoch 9/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2707 Acc: 0.9025
# val Loss: 0.2635 Acc: 0.9088
#
# Epoch 10/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2587 Acc: 0.9056
# val Loss: 0.2641 Acc: 0.9088
#
# Epoch 11/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2653 Acc: 0.9052
# val Loss: 0.2910 Acc: 0.9053
#
# Epoch 12/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2591 Acc: 0.9025
# val Loss: 0.3256 Acc: 0.8947
#
# Epoch 13/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2576 Acc: 0.9047
# val Loss: 0.2506 Acc: 0.9070
#
# Epoch 14/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2660 Acc: 0.9047
# val Loss: 0.2863 Acc: 0.9088
#
# Epoch 15/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2635 Acc: 0.9083
# val Loss: 0.2805 Acc: 0.9053
#
# Epoch 16/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2610 Acc: 0.9017
# val Loss: 0.3116 Acc: 0.8947
#
# Epoch 17/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2847 Acc: 0.8903
# val Loss: 0.2728 Acc: 0.9053
#
# Epoch 18/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2493 Acc: 0.9065
# val Loss: 0.3222 Acc: 0.8877
#
# Epoch 19/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2675 Acc: 0.9078
# val Loss: 0.2899 Acc: 0.9000
#
# Epoch 20/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2604 Acc: 0.9074
# val Loss: 0.3218 Acc: 0.8842
#
# Epoch 21/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2500 Acc: 0.9135
# val Loss: 0.2762 Acc: 0.8982
#
# Epoch 22/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2537 Acc: 0.9109
# val Loss: 0.3327 Acc: 0.8930
#
# Epoch 23/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2523 Acc: 0.9100
# val Loss: 0.2852 Acc: 0.9053
#
# Epoch 24/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2618 Acc: 0.9056
# val Loss: 0.2844 Acc: 0.8860
#
# Training complete in 4m 38s
# Best val Acc: 0.914035
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 226MB/s]
# Epoch 0/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.8829 Acc: 0.6730
# val Loss: 0.5361 Acc: 0.7614
#
# Epoch 1/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.4287 Acc: 0.8464
# val Loss: 0.3726 Acc: 0.8614
#
# Epoch 2/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3639 Acc: 0.8661
# val Loss: 0.3415 Acc: 0.8825
#
# Epoch 3/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3274 Acc: 0.8824
# val Loss: 0.3340 Acc: 0.8860
#
# Epoch 4/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.2944 Acc: 0.8977
# val Loss: 0.3123 Acc: 0.8982
#
# Epoch 5/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.2848 Acc: 0.8916
# val Loss: 0.3184 Acc: 0.8877
#
# Epoch 6/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.2689 Acc: 0.9043
# val Loss: 0.3180 Acc: 0.8842
#
# Epoch 7/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2276 Acc: 0.9245
# val Loss: 0.3032 Acc: 0.9035
#
# Epoch 8/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2360 Acc: 0.9188
# val Loss: 0.2383 Acc: 0.9123
#
# Epoch 9/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2196 Acc: 0.9205
# val Loss: 0.2686 Acc: 0.8982
#
# Epoch 10/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2350 Acc: 0.9109
# val Loss: 0.2913 Acc: 0.9053
#
# Epoch 11/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2083 Acc: 0.9263
# val Loss: 0.3140 Acc: 0.8877
#
# Epoch 12/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2218 Acc: 0.9144
# val Loss: 0.2941 Acc: 0.8930
#
# Epoch 13/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2304 Acc: 0.9162
# val Loss: 0.3020 Acc: 0.9035
#
# Epoch 14/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2177 Acc: 0.9227
# val Loss: 0.2509 Acc: 0.9105
#
# Epoch 15/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2140 Acc: 0.9236
# val Loss: 0.2490 Acc: 0.9053
#
# Epoch 16/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2265 Acc: 0.9249
# val Loss: 0.3046 Acc: 0.8965
#
# Epoch 17/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2118 Acc: 0.9214
# val Loss: 0.2604 Acc: 0.9053
#
# Epoch 18/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2169 Acc: 0.9289
# val Loss: 0.3043 Acc: 0.8825
#
# Epoch 19/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2402 Acc: 0.9131
# val Loss: 0.2814 Acc: 0.9018
#
# Epoch 20/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1967 Acc: 0.9271
# val Loss: 0.2717 Acc: 0.9000
#
# Epoch 21/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2193 Acc: 0.9258
# val Loss: 0.2673 Acc: 0.9000
#
# Epoch 22/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2328 Acc: 0.9113
# val Loss: 0.2768 Acc: 0.9018
#
# Epoch 23/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2159 Acc: 0.9258
# val Loss: 0.2928 Acc: 0.9053
#
# Epoch 24/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2130 Acc: 0.9271
# val Loss: 0.2763 Acc: 0.9070
#
# Training complete in 4m 51s
# Best val Acc: 0.912281
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 205MB/s]
# Epoch 0/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.9645 Acc: 0.6554
# val Loss: 0.4804 Acc: 0.8246
#
# Epoch 1/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.4106 Acc: 0.8591
# val Loss: 0.3528 Acc: 0.8807
#
# Epoch 2/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3535 Acc: 0.8709
# val Loss: 0.3106 Acc: 0.8947
#
# Epoch 3/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.3152 Acc: 0.8889
# val Loss: 0.3145 Acc: 0.8947
#
# Epoch 4/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.2947 Acc: 0.8960
# val Loss: 0.2976 Acc: 0.9105
#
# Epoch 5/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.2539 Acc: 0.9065
# val Loss: 0.2687 Acc: 0.9000
#
# Epoch 6/24
# ----------
# Learning Rate: 0.001000
# train Loss: 0.2545 Acc: 0.9030
# val Loss: 0.2788 Acc: 0.8947
#
# Epoch 7/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2204 Acc: 0.9197
# val Loss: 0.2590 Acc: 0.9053
#
# Epoch 8/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2108 Acc: 0.9284
# val Loss: 0.2639 Acc: 0.8965
#
# Epoch 9/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2344 Acc: 0.9157
# val Loss: 0.2684 Acc: 0.9211
#
# Epoch 10/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2107 Acc: 0.9223
# val Loss: 0.2337 Acc: 0.9211
#
# Epoch 11/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2050 Acc: 0.9293
# val Loss: 0.2429 Acc: 0.9193
#
# Epoch 12/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.1981 Acc: 0.9315
# val Loss: 0.2453 Acc: 0.9175
#
# Epoch 13/24
# ----------
# Learning Rate: 0.000100
# train Loss: 0.2157 Acc: 0.9249
# val Loss: 0.2606 Acc: 0.9140
#
# Epoch 14/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1959 Acc: 0.9328
# val Loss: 0.2484 Acc: 0.9070
#
# Epoch 15/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1939 Acc: 0.9289
# val Loss: 0.2489 Acc: 0.9211
#
# Epoch 16/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.2057 Acc: 0.9284
# val Loss: 0.2485 Acc: 0.9158
#
# Epoch 17/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1999 Acc: 0.9333
# val Loss: 0.2383 Acc: 0.9105
#
# Epoch 18/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1985 Acc: 0.9284
# val Loss: 0.2872 Acc: 0.9018
#
# Epoch 19/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1996 Acc: 0.9254
# val Loss: 0.2401 Acc: 0.9088
#
# Epoch 20/24
# ----------
# Learning Rate: 0.000010
# train Loss: 0.1935 Acc: 0.9328
# val Loss: 0.2659 Acc: 0.9123
#
# Epoch 21/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.2071 Acc: 0.9306
# val Loss: 0.2650 Acc: 0.9158
#
# Epoch 22/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.1918 Acc: 0.9342
# val Loss: 0.2529 Acc: 0.9263
#
# Epoch 23/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.1822 Acc: 0.9359
# val Loss: 0.2528 Acc: 0.9053
#
# Epoch 24/24
# ----------
# Learning Rate: 0.000001
# train Loss: 0.1921 Acc: 0.9254
# val Loss: 0.2872 Acc: 0.9018
#
# Training complete in 6m 40s
# Best val Acc: 0.926316
